# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('cancer patient data sets.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  Smoking  Passive Smoker  Chest Pain  Coughing of Blood  Fatigue  \
# 0        4        3               2           2                  4        3
# 1        2        2               4           2                  3        1
# 2        7        2               3           4                  8        8
# 3        7        7               7           7                  8        4
# 4        7        8               7           7                  9        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High

# %%
df.drop(columns=['index', 'Patient Id'], inplace=True)
df.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  Smoking  Passive Smoker  Chest Pain  Coughing of Blood  Fatigue  \
# 0        4        3               2           2                  4        3
# 1        2        2               4           2                  3        1
# 2        7        2               3           4                  8        8
# 3        7        7               7           7                  8        4
# 4        7        8               7           7                  9        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(848)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 497   35       1              2            1             2
# 977   45       1              3            1             4
# 979   53       1              3            1             4
# 983   26       1              3            2             4
# 984   37       1              1            2             3
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# 2                       5             5                     4              6
# 3                       7             6                     7              7
# 4                       7             7                     6              7
# ..                    ...           ...                   ...            ...
# 497                     1             2                     1              2
# 977                     3             2                     3              4
# 979                     2             3                     2              3
# 983                     2             3                     2              3
# 984                     4             2                     4              3
#
#      Obesity  Smoking  Passive Smoker  Chest Pain  Coughing of Blood  Fatigue  \
# 0          4        3               2           2                  4        3
# 1          2        2               4           2                  3        1
# 2          7        2               3           4                  8        8
# 3          7        7               7           7                  8        4
# 4          7        8               7           7                  9        3
# ..       ...      ...             ...         ...                ...      ...
# 497        3        2               4           2                  1        3
# 977        3        1               4           3                  1        3
# 979        3        2               2           4                  2        2
# 983        3        2               2           3                  3        4
# 984        3        3               2           3                  4        4
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 497            4                    5         1                      3
# 977            2                    2         4                      2
# 979            2                    3         4                      1
# 983            5                    6         5                      5
# 984            1                    2         4                      6
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 497                         2              1          2        2     Low
# 977                         2              3          4        3     Low
# 979                         5              2          6        2     Low
# 983                         4              6          5        4  Medium
# 984                         5              4          2        5  Medium
#
# [152 rows x 24 columns]

# %%
df.describe()
# Out:
#               Age      Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  152.000000  152.000000     152.000000   152.000000    152.000000
# mean    38.236842    1.414474       3.717105     4.480263      5.046053
# std     11.798382    0.494259       1.978084     2.601503      2.027424
# min     14.000000    1.000000       1.000000     1.000000      1.000000
# 25%     28.000000    1.000000       2.000000     2.000000      3.750000
# 50%     37.000000    1.000000       3.000000     5.000000      6.000000
# 75%     46.000000    2.000000       6.000000     7.000000      7.000000
# max     73.000000    2.000000       8.000000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count            152.000000    152.000000            152.000000
# mean               4.710526      4.486842              4.243421
# std                2.158095      2.143794              1.880527
# min                1.000000      1.000000              1.000000
# 25%                3.000000      2.000000              3.000000
# 50%                5.000000      5.000000              4.000000
# 75%                7.000000      7.000000              6.000000
# max                8.000000      7.000000              7.000000
#
#        Balanced Diet     Obesity     Smoking  Passive Smoker  Chest Pain  \
# count     152.000000  152.000000  152.000000      152.000000  152.000000
# mean        4.427632    4.414474    3.973684        4.151316    4.388158
# std         2.151857    2.120365    2.473562        2.263327    2.278751
# min         1.000000    1.000000    1.000000        1.000000    1.000000
# 25%         2.000000    3.000000    2.000000        2.000000    2.000000
# 50%         4.000000    4.000000    3.000000        4.000000    4.000000
# 75%         7.000000    7.000000    7.000000        7.000000    7.000000
# max         7.000000    7.000000    8.000000        8.000000    9.000000
#
#        Coughing of Blood     Fatigue  Weight Loss  Shortness of Breath  \
# count         152.000000  152.000000   152.000000           152.000000
# mean            4.796053    3.763158     3.828947             4.269737
# std             2.453107    2.230840     2.233924             2.263943
# min             1.000000    1.000000     1.000000             1.000000
# 25%             3.000000    2.000000     2.000000             2.000000
# 50%             4.000000    3.000000     3.000000             4.000000
# 75%             7.000000    5.000000     6.000000             6.000000
# max             9.000000    9.000000     8.000000             9.000000
#
#          Wheezing  Swallowing Difficulty  Clubbing of Finger Nails  \
# count  152.000000             152.000000                152.000000
# mean     3.776316               3.750000                  3.894737
# std      2.036740               2.196475                  2.344948
# min      1.000000               1.000000                  1.000000
# 25%      2.000000               2.000000                  2.000000
# 50%      4.000000               4.000000                  4.000000
# 75%      5.000000               5.000000                  5.000000
# max      8.000000               8.000000                  9.000000
#
#        Frequent Cold   Dry Cough     Snoring
# count     152.000000  152.000000  152.000000
# mean        3.480263    3.684211    2.921053
# std         1.848466    2.047195    1.542022
# min         1.000000    1.000000    1.000000
# 25%         2.000000    2.000000    2.000000
# 50%         3.000000    3.000000    3.000000
# 75%         5.000000    5.000000    4.000000
# max         7.000000    7.000000    7.000000

# %%
df.groupby('Level').mean()
# Out:
#               Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Level
# High    38.528302  1.283019       5.584906     6.830189      6.566038
# Low     37.978723  1.574468       2.574468     2.127660      2.914894
# Medium  38.173077  1.403846       2.846154     4.211538      5.423077
#
#         OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# Level
# High                6.415094      6.358491              5.773585
# Low                 2.808511      2.574468              2.851064
# Medium              4.692308      4.307692              3.942308
#
#         Balanced Diet   Obesity   Smoking  Passive Smoker  Chest Pain  \
# Level
# High         6.641509  6.641509  6.037736        6.452830    6.396226
# Low          2.829787  2.425532  3.255319        2.723404    2.702128
# Medium       3.615385  3.942308  2.519231        3.096154    3.865385
#
#         Coughing of Blood   Fatigue  Weight Loss  Shortness of Breath  \
# Level
# High             7.471698  5.490566     4.603774             5.415094
# Low              2.765957  2.191489     2.468085             2.638298
# Medium           3.903846  3.423077     4.269231             4.576923
#
#         Wheezing  Swallowing Difficulty  Clubbing of Finger Nails  \
# Level
# High    3.886792               4.018868                  4.150943
# Low     2.595745               3.000000                  2.425532
# Medium  4.730769               4.153846                  4.961538
#
#         Frequent Cold  Dry Cough   Snoring
# Level
# High         4.283019   4.641509  3.188679
# Low          2.319149   2.702128  2.063830
# Medium       3.711538   3.596154  3.423077

# %%
df.drop(columns=['Age'], inplace=True)
df.head()
# Out:
#    Gender  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0       1              2            4             5                     4
# 1       1              3            1             5                     3
# 2       1              4            5             6                     5
# 3       1              7            7             7                     7
# 4       1              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0             3                     2              2        4        3
# 1             4                     2              2        2        2
# 2             5                     4              6        7        2
# 3             6                     7              7        7        7
# 4             7                     6              7        7        8
#
#    Passive Smoker  Chest Pain  Coughing of Blood  Fatigue  Weight Loss  \
# 0               2           2                  4        3            4
# 1               4           2                  3        1            3
# 2               3           4                  8        8            7
# 3               7           7                  8        4            2
# 4               7           7                  9        3            2
#
#    Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0                    2         2                      3
# 1                    7         8                      6
# 2                    9         2                      1
# 3                    3         1                      4
# 4                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High

# %%
sns.countplot(df, x='Level')
plt.show()

# %%
le = LabelEncoder()
df['Level'] = le.fit_transform(df['Level'])

# %%
plt.figure(figsize=(14, 8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
X = df.drop(columns=['Level'])
y = df['Level']

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
accuracy_score(y_valid, dt.predict(X_valid))
# Out:
# 0.9565217391304348

# %%
print(f'Training Accuracy: {accuracy_score(y_train, dt.predict(X_train))}')
print(f'Testing Accuracy: {accuracy_score(y_test, dt.predict(X_test))}')
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 1.0
